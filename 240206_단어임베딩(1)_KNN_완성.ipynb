# %% [markdown]
# <a href="https://colab.research.google.com/github/eunzzae/PJT_C.lab/blob/main/240206_%EB%8B%A8%EC%96%B4%EC%9E%84%EB%B2%A0%EB%94%A9(1)_KNN_%EC%99%84%EC%84%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * <참고>
# https://jxnjxn.tistory.com/49#6._%ED%99%9C%EC%9A%A9_:_%EC%9B%8C%EB%93%9C_%EC%9E%84%EB%B2%A0%EB%94%A9%EB%90%9C_%EB%B2%A1%ED%84%B0%EB%A1%9C_%EB%AC%B8%EC%9E%A5_%EB%8B%A8%EC%9C%84_%EC%9E%84%EB%B2%A0%EB%94%A9

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # import 라이브러리

# %%
# colab 환경에 glove 설치
! pip install glove-python3
# Out:
# Requirement already satisfied: glove-python3 in /usr/local/lib/python3.10/dist-packages (0.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from glove-python3) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from glove-python3) (1.11.4)

# %%
pip list | grep glove
# Out:
# glove-python3                    0.1.0

# %%
from glove import Corpus, Glove
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /usr/local/lib/python3.10/dist-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /usr/local/lib/python3.10/dist-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /usr/local/lib/python3.10/dist-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
# import nltk
# nltk.download('punkt')

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] =False

# %% [markdown]
# # GloVe 임베딩 파일 로드

# %%
embeddings_index = {}
with open('/content/drive/MyDrive/Colab Notebooks/단어임베딩/data/word-embeddings/glove/glove.txt', encoding='utf8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# %% [markdown]
# # 단어 데이터 준비 및 정수 인코딩

# %%
# 데이터분석 4종 세트
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base_path = '/content/drive/MyDrive/Colab Notebooks/data/connects_lab/'
customer_df = pd.read_csv(base_path+'Data_1_TalkD_customer_240124_modi.csv', encoding='utf-8')
course_df = pd.read_csv(base_path+'Data_2_TalkD_course_240124_modi.csv',encoding='utf-8')
rating_df = pd.read_csv(base_path+'Data_3_ratings_df_240124_modi.csv',encoding='utf-8')

# %%
# Extract and flatten the keywords from the 'Parenting_Concerns' and '관련 육아고민' columns
parenting_concerns = customer_df['Parenting_Concerns'].str.split(', ')
customer_words = [word.strip() for sublist in parenting_concerns for word in sublist]
course_concerns = course_df['관련 육아고민'].str.split(', ')
course_words = [word.strip() for sublist in course_concerns for word in sublist]

# Create a unique list of keywords
combined_words = list(set(customer_words + course_words))

# %%
# Initialize and fit the tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(combined_words)

# Convert the texts to sequences and flatten to 1D array
sequences = tokenizer.texts_to_sequences(combined_words)
data = np.array([item for sublist in sequences for item in sublist])

# %%
print(data)
# Out:
# [ 3  4  5  1  2  6  7  2  8  1  9 10 11 12 13 14 15 16]

# %% [markdown]
# # 임베딩 매트릭스 생성

# %%
# Define the embedding layer
embedding_dim = 100
word_index = tokenizer.word_index
num_words = len(word_index) + 1
embeddings_index = {word: np.random.rand(embedding_dim) for word in word_index.keys()}  # Dummy embeddings
embedding_matrix = np.zeros((num_words, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# # 모델 정의 및 컴파일

# %%
# Define the model
model = Sequential()
model.add(Embedding(num_words, embedding_dim, input_length=1, weights=[embedding_matrix], trainable=False))
model.add(Dense(16, activation='relu'))
num_classes = 10  # Define your number of classes here
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Reshape data for training and use the data itself as labels (modify as needed)
data = data.reshape(-1, 1)
labels = data
model.fit(data, labels, epochs=3, batch_size=32)
# Out:
# Epoch 1/3
# 1/1 [==============================] - 1s 1s/step - loss: nan - accuracy: 0.1667
# Epoch 2/3
# 1/1 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0000e+00
# Epoch 3/3
# 1/1 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0000e+00

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from tensorflow.keras.models import Model
from sklearn.decomposition import PCA

# %%
# 'model'은 앞서 정의하고 학습한 Keras 모델입니다.
embedding_layer = model.layers[0]
weights = embedding_layer.get_weights()[0]

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import normalize

# 임베딩 가중치 정규화
normalized_weights = normalize(weights)

# 이웃의 수 정의
n_neighbors = 5  # 필요에 따라 이 값을 조정하세요

# KNN 모델 초기화 및 학습
knn = NearestNeighbors(n_neighbors=n_neighbors)
knn.fit(normalized_weights)

# 각 단어에 대한 가장 가까운 이웃 찾기
neighbors = knn.kneighbors(normalized_weights, return_distance=False)

# NearestNeighbors의 결과를 처리하고 인덱스를 맞춤
word_neighbors = {}
for i, neighbor in enumerate(neighbors):
    word = index_to_word.get(i + 1, 'N/A')
    if word != 'N/A':
        # 존재하는 단어에 대해서만 이웃 단어를 찾음
        word_neighbors[word] = [index_to_word.get(n + 1, 'N/A') for n in neighbor]

# 각 단어의 가장 가까운 이웃 출력
for word, neighbor in word_neighbors.items():
    print(f"단어: {word}, 이웃: {neighbor}")
# Out:
# 단어: 발달, 이웃: ['발달', '관계', '건강', '수면', '훈육']
# 단어: 관계, 이웃: ['관계', '육아방법', '식습관', '부모역할', '놀이']
# 단어: 놀이, 이웃: ['놀이', '육아방법', '육아스트레스', '상호작용', '부모역할']
# 단어: 육아방법, 이웃: ['육아방법', '놀이', '상호작용', '관계', '부모역할']
# 단어: 감정표현, 이웃: ['감정표현', '식습관', '건강', '부부관계', '상호작용']
# 단어: 우울감, 이웃: ['우울감', '식습관', '부모역할', '육아스트레스', '놀이']
# 단어: 육아스트레스, 이웃: ['육아스트레스', '부모역할', '놀이', '우울감', '상호작용']
# 단어: 육아관, 이웃: ['육아관', '식습관', '육아방법', '학습지도', 'N/A']
# 단어: 부부관계, 이웃: ['부부관계', '감정표현', '부모역할', '식습관', '육아스트레스']
# 단어: 식습관, 이웃: ['식습관', '우울감', '감정표현', '육아관', '육아방법']
# 단어: 상호작용, 이웃: ['상호작용', '육아방법', '놀이', '육아스트레스', '부모역할']
# 단어: 훈육, 이웃: ['훈육', '부모역할', '놀이', '육아방법', '관계']
# 단어: 부모역할, 이웃: ['부모역할', '우울감', '육아방법', '육아스트레스', '학습지도']
# 단어: 학습지도, 이웃: ['학습지도', '육아방법', '부모역할', '수면', '육아관']
# 단어: 건강, 이웃: ['건강', '감정표현', '육아스트레스', '상호작용', '놀이']
# 단어: 수면, 이웃: ['수면', '학습지도', 'N/A', '식습관', '건강']

# %%
for word, neighbors in word_neighbors.items():
    print(f"단어: {word}")
    word_index = tokenizer.word_index[word] - 1  # 'word'의 인덱스
    for neighbor in neighbors:
        if neighbor != 'N/A':
            neighbor_index = tokenizer.word_index[neighbor] - 1  # 'neighbor'의 인덱스
            distance = np.linalg.norm(normalized_weights[word_index] - normalized_weights[neighbor_index])
            print(f"  이웃: {neighbor}, 거리: {distance:.2f}")
        else:
            print("  이웃: N/A, 거리: N/A")
# Out:
# 단어: 발달
#   이웃: 발달, 거리: 0.00
#   이웃: 관계, 거리: 1.00
#   이웃: 건강, 거리: 1.00
#   이웃: 수면, 거리: 1.00
#   이웃: 훈육, 거리: 1.00
# 단어: 관계
#   이웃: 관계, 거리: 0.00
# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# t-SNE 모델을 사용하여 임베딩을 2D 공간으로 축소
# perplexity 값을 데이터셋 크기의 약 절반으로 설정
tsne = TSNE(n_components=2, random_state=0, perplexity=len(normalized_weights)//2)
reduced_embeddings = tsne.fit_transform(normalized_weights)


# 단어 임베딩을 2D 공간에 플롯
plt.figure(figsize=(12, 12))
for i, word in enumerate(index_to_word.values()):
    plt.scatter(reduced_embeddings[i, 0], reduced_embeddings[i, 1])
    plt.annotate(word, xy=(reduced_embeddings[i, 0], reduced_embeddings[i, 1]), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')

# 각 단어에 대한 가장 가까운 이웃들의 위치를 시각화
for word, neighbors in word_neighbors.items():
    word_index = tokenizer.word_index[word] - 1
    for neighbor in neighbors:
        neighbor_index = tokenizer.word_index[neighbor] - 1
        plt.plot([reduced_embeddings[word_index, 0], reduced_embeddings[neighbor_index, 0]],
                 [reduced_embeddings[word_index, 1], reduced_embeddings[neighbor_index, 1]], 'r-')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-35b094888aa8> in <cell line: 17>()
#      18     word_index = tokenizer.word_index[word] - 1
#      19     for neighbor in neighbors:
# ---> 20         neighbor_index = tokenizer.word_index[neighbor] - 1
#      21         plt.plot([reduced_embeddings[word_index, 0], reduced_embeddings[neighbor_index, 0]],
#      22                  [reduced_embeddings[word_index, 1], reduced_embeddings[neighbor_index, 1]], 'r-')
#
# KeyError: 'N/A'

# %%
n_samples = weights.shape[0]
perplexity_value = min(40, n_samples - 1)  # perplexity는 n_samples보다 작아야 함

tsne = TSNE(n_components=2, verbose=1, perplexity=perplexity_value, n_iter=300)
tsne_results = tsne.fit_transform(weights)

# %%
plt.figure(figsize=(10, 10))

# 무작위 오프셋을 위한 범위 설정
offset_range = 10  # 오프셋 범위를 조정할 수 있습니다.

for i, word in enumerate(word_index.keys()):
    if i >= 1000:  # 처음 1000개 단어만 표시
        break
    x, y = tsne_results[i, 0], tsne_results[i, 1]
    # 무작위 오프셋 추가
    x_offset = np.random.uniform(-offset_range, offset_range)
    y_offset = np.random.uniform(-offset_range, offset_range)

    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(x_offset, y_offset),
                 textcoords='offset points', ha='right', va='bottom')

plt.show()

# %% [markdown]
# # PCA 시각화

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# PCA 모델을 사용하여 임베딩을 2D 공간으로 축소
pca = PCA(n_components=2)
reduced_embeddings = pca.fit_transform(normalized_weights)

# 단어 임베딩을 2D 공간에 플롯
plt.figure(figsize=(12, 12))
for i, word in enumerate(index_to_word.values()):
    plt.scatter(reduced_embeddings[i, 0], reduced_embeddings[i, 1])
    plt.annotate(word, xy=(reduced_embeddings[i, 0], reduced_embeddings[i, 1]), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')

plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# PCA 인스턴스 생성 및 학습
pca = PCA(n_components=2)
pca_results = pca.fit_transform(weights)

# %%
import numpy as np

# 시각화
plt.figure(figsize=(10,10))

# 무작위 오프셋을 위한 범위 설정
offset_range = 10  # 오프셋 범위를 조정할 수 있습니다.

for i, word in enumerate(word_index.keys()):
    if i >= 1000:  # 처음 1000개 단어만 표시
        break
    x, y = pca_results[i, 0], pca_results[i, 1]
    # 무작위 오프셋 추가
    x_offset = np.random.uniform(-offset_range, offset_range)
    y_offset = np.random.uniform(-offset_range, offset_range)

    plt.scatter(x, y)
    plt.annotate(word, xy=(x, y), xytext=(x_offset, y_offset),
                 textcoords='offset points', ha='right', va='bottom')

plt.show()
